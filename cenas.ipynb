# %%
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.decomposition import PCA
import SteamVariables as sv
from sklearn.utils import shuffle
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
df = pd.read_csv(sv.CSV_PATH)##Chama o dataset
    
df = df.dropna()##Elimina os nas para mais segurança
languages = [ ##Linguagens a ser removidas
            "bulgarian",
            "croatian",
            "danish",
            "czech",
            "slovak",
            "slovenian",
            "slovak",
            "slovenian",
            "spanish",
            "estonian",
            "finnish",
            "french",
            "greek",
            "hungarian",
            "irish",
            "italian",
            "latvian",
            "lithuanian",
            "maltese",
            "dutch",
            "polish",
            "portuguese",
            "romanian",
            "swedish",
            "english",
            "brazilian",
        ]

# Eliminar linhas com linguagem diferente das selecionadas
df = df[df[sv.LANGUAGE].isin(languages)]
dt_for_comments = df

print(dt_for_comments)
# Out:
#           Unnamed: 0  app_id                  app_name  review_id language  \
# 3                  3  292030  The Witcher 3: Wild Hunt   85184605  english
# 5                  5  292030  The Witcher 3: Wild Hunt   85184171  english
# 6                  6  292030  The Witcher 3: Wild Hunt   85184064  english
# 9                  9  292030  The Witcher 3: Wild Hunt   85182785  spanish
# 18                18  292030  The Witcher 3: Wild Hunt   85180436  english
# ...              ...     ...                       ...        ...      ...
# 21747365    21747370  546560           Half-Life: Alyx   65645130  spanish
# 21747366    21747371  546560           Half-Life: Alyx   65645125  english
# 21747367    21747372  546560           Half-Life: Alyx   65645115  english
# 21747368    21747373  546560           Half-Life: Alyx   65645100  english
# 21747369    21747374  546560           Half-Life: Alyx   65645066  english
#
#                                                      review  \
# ...

# %%
print(dt_for_comments.isnull().sum())


value = 76561198049901200

reviews = dt_for_comments[(dt_for_comments[sv.AUTHOR_STEAMID] == int(value))]
print(dt_for_comments[(dt_for_comments[sv.AUTHOR_STEAMID] == int(value))])
# Out:
# Unnamed: 0                        0
# app_id                            0
# app_name                          0
# review_id                         0
# language                          0
# review                            0
# timestamp_created                 0
# timestamp_updated                 0
# recommended                       0
# votes_helpful                     0
# votes_funny                       0
# weighted_vote_score               0
# comment_count                     0
# steam_purchase                    0
# received_for_free                 0
# written_during_early_access       0
# author.steamid                    0
# author.num_games_owned            0
# author.num_reviews                0
# author.playtime_forever           0
# author.playtime_last_two_weeks    0
# author.playtime_at_review         0
# author.last_played                0
# dtype: int64
# Empty DataFrame
# ...
