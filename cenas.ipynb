# %%
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.decomposition import PCA
import SteamVariables as sv
from sklearn.utils import shuffle
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
df = pd.read_csv(sv.CSV_PATH)##Chama o dataset
    
df = df.dropna()##Elimina os nas para mais segurança
languages = [ ##Linguagens a ser removidas
            "bulgarian",
            "croatian",
            "danish",
            "czech",
            "slovak",
            "slovenian",
            "slovak",
            "slovenian",
            "spanish",
            "estonian",
            "finnish",
            "french",
            "greek",
            "hungarian",
            "irish",
            "italian",
            "latvian",
            "lithuanian",
            "maltese",
            "dutch",
            "polish",
            "portuguese",
            "romanian",
            "swedish",
            "english",
            "brazilian",
        ]

# Eliminar linhas com linguagem diferente das selecionadas
df = df[df[sv.LANGUAGE].isin(languages)]
dt_for_comments = df

print(dt_for_comments)
# Out:
#           Unnamed: 0  app_id                  app_name  review_id language  \
# 3                  3  292030  The Witcher 3: Wild Hunt   85184605  english
# 5                  5  292030  The Witcher 3: Wild Hunt   85184171  english
# 6                  6  292030  The Witcher 3: Wild Hunt   85184064  english
# 9                  9  292030  The Witcher 3: Wild Hunt   85182785  spanish
# 18                18  292030  The Witcher 3: Wild Hunt   85180436  english
# ...              ...     ...                       ...        ...      ...
# 21747365    21747370  546560           Half-Life: Alyx   65645130  spanish
# 21747366    21747371  546560           Half-Life: Alyx   65645125  english
# 21747367    21747372  546560           Half-Life: Alyx   65645115  english
# 21747368    21747373  546560           Half-Life: Alyx   65645100  english
# 21747369    21747374  546560           Half-Life: Alyx   65645066  english
#
#                                                      review  \
# 3         One of the best RPG's of all time, worthy of a...
# 5                    good story, good graphics. lots to do.
# 6                                                  dis gud,
# 9                                                great game
# 18        favorite game of all time cant wait for the Ne...
# ...                                                     ...
# 21747365  Juegazo! Todo lo que diga es poco, Por favor d...
# 21747366                                         Holy balls
# 21747367  A tripod thing bears down on you, it looks imm...
# 21747368             Honestly this is the best vr game ever
# 21747369  Smooth turning is not working right now.\nIt a...
#
#           timestamp_created  timestamp_updated  recommended  votes_helpful  \
# 3                1611379970         1611379970         True              0
# 5                1611379264         1611379264         True              0
# 6                1611379091         1611379091         True              0
# 9                1611377005         1611377005         True              0
# 18               1611373086         1611373086         True              0
# ...                     ...                ...          ...            ...
# 21747365         1584986707         1584986707         True             87
# 21747366         1584986704         1584986704         True              0
# 21747367         1584986693         1584986693         True              0
# 21747368         1584986673         1584986673         True              0
# 21747369         1584986631         1586382422         True              0
#
#           ...  steam_purchase  received_for_free  written_during_early_access  \
# 3         ...            True              False                        False
# 5         ...            True              False                        False
# 6         ...            True              False                        False
# 9         ...            True              False                        False
# 18        ...            True              False                        False
# ...       ...             ...                ...                          ...
# 21747365  ...           False              False                        False
# 21747366  ...            True              False                        False
# 21747367  ...           False              False                        False
# 21747368  ...            True              False                        False
# 21747369  ...            True              False                        False
#
#              author.steamid  author.num_games_owned  author.num_reviews  \
# 3         76561199054755373                       5                   3
# 5         76561198170193529                      11                   1
# 6         76561198119302812                      27                   2
# 9         76561198301724112                      38                   5
# 18        76561198065591528                      33                   1
# ...                     ...                     ...                 ...
# 21747365  76561197970410091                     196                  16
# 21747366  76561197967033932                     431                   7
# 21747367  76561198046495482                      70                  10
# 21747368  76561198176379749                      79                  17
# 21747369  76561198041763187                     140                   3
#
#           author.playtime_forever  author.playtime_last_two_weeks  \
# 3                          5587.0                          3200.0
# 5                           823.0                           823.0
# 6                          4192.0                          3398.0
# 9                          2399.0                           333.0
# 18                        23329.0                           177.0
# ...                           ...                             ...
# 21747365                   1903.0                             6.0
# 21747366                    432.0                             0.0
# 21747367                   3296.0                            15.0
# 21747368                   2654.0                             0.0
# 21747369                    210.0                             0.0
#
#           author.playtime_at_review  author.last_played
# 3                            5524.0        1.611384e+09
# 5                             823.0        1.611379e+09
# 6                            4192.0        1.611352e+09
# 9                            2364.0        1.611379e+09
# 18                          23329.0        1.611219e+09
# ...                             ...                 ...
# 21747365                       30.0        1.611353e+09
# 21747366                       29.0        1.586628e+09
# 21747367                       24.0        1.611080e+09
# 21747368                       34.0        1.591634e+09
# 21747369                       12.0        1.589715e+09
#
# [13029320 rows x 23 columns]

# %%
print(dt_for_comments.sample(5))
# Out:
#           Unnamed: 0  app_id                      app_name  review_id  \
# 7734320      7734321  252490                          Rust   20191843
# 7460156      7460157  252490                          Rust   61189825
# 499229        499230      70                     Half-Life   51518947
# 19775298    19775302  518790  theHunter: Call of the Wild™   77664764
# 2346218      2346219  264710                    Subnautica   58920933
#
#            language                                             review  \
# 7734320     english  Fun game and gets your heart pumping. I highly...
# 7460156     english                                         its good\n
# 499229      english                           Very good game. Good buy
# 19775298  brazilian           Simulador de caça, bonito e interessante
# 2346218      french  J'apprécie énormément ce jeu, très reposant pa...
#
#           timestamp_created  timestamp_updated  recommended  votes_helpful  \
# 7734320          1451680276         1451680276         True              1
# 7460156          1578026767         1578026767         True              0
# 499229           1561708305         1561708305         True              0
# 19775298         1602877114         1602877114         True              0
# 2346218          1575218163         1575218163         True              0
#
#           ...  steam_purchase  received_for_free  written_during_early_access  \
# 7734320   ...            True              False                         True
# 7460156   ...            True              False                        False
# 499229    ...            True              False                        False
# 19775298  ...            True              False                        False
# 2346218   ...            True              False                        False
#
#              author.steamid  author.num_games_owned  author.num_reviews  \
# 7734320   76561198049059256                      81                   1
# 7460156   76561198123516965                      15                   1
# 499229    76561198041836122                      88                   4
# 19775298  76561198628643728                      10                   8
# 2346218   76561198195426094                      71                   4
#
#           author.playtime_forever  author.playtime_last_two_weeks  \
# 7734320                   35156.0                             0.0
# 7460156                    6893.0                             0.0
# 499229                      532.0                             0.0
# 19775298                    329.0                             0.0
# 2346218                    9359.0                             0.0
#
#           author.playtime_at_review  author.last_played
# 7734320                      2842.0        1.605807e+09
# 7460156                      6856.0        1.608936e+09
# 499229                        532.0        1.543177e+09
# 19775298                      329.0        1.602729e+09
# 2346218                      8996.0        1.603746e+09
#
# [5 rows x 23 columns]

# %%
value = 76561198628643728

reviews = dt_for_comments[(dt_for_comments[sv.AUTHOR_STEAMID] == int(value))]
print(dt_for_comments[(dt_for_comments[sv.AUTHOR_STEAMID] == int(value))])
# Out:
#           Unnamed: 0  app_id                                     app_name  \
# 4195413      4195414  227300                       Euro Truck Simulator 2
# 17717812    17717816  570940                      DARK SOULS™: REMASTERED
# 19775298    19775302  518790                 theHunter: Call of the Wild™
# 19986651    19986655  489830  The Elder Scrolls V: Skyrim Special Edition
# 20462805    20462809  107410                                       Arma 3
#
#           review_id   language  \
# 4195413    68011634  brazilian
# 17717812   76989070  brazilian
# 19775298   77664764  brazilian
# 19986651   73589261  brazilian
# 20462805   73589081  brazilian
#
#                                                      review  \
# 4195413   Ótimo game simulador, com ótimos recursos e at...
# 17717812  Um dos melhores RPG's que já joguei, recomendo...
# 19775298           Simulador de caça, bonito e interessante
# 19986651  Não me canso de jogar esse game, mto bom... Be...
# 20462805  Melhor simulador militar na minha opinião, amo...
#
#           timestamp_created  timestamp_updated  recommended  votes_helpful  \
# 4195413          1587839323         1587839323         True              0
# 17717812         1601758194         1601758194         True              0
# 19775298         1602877114         1602877114         True              0
# 19986651         1596252700         1596252700         True              0
# 20462805         1596252359         1596252359         True              0
#
#           ...  steam_purchase  received_for_free  written_during_early_access  \
# 4195413   ...            True              False                        False
# 17717812  ...           False              False                        False
# 19775298  ...            True              False                        False
# 19986651  ...            True              False                        False
# 20462805  ...            True              False                        False
#
#              author.steamid  author.num_games_owned  author.num_reviews  \
# 4195413   76561198628643728                      10                   8
# 17717812  76561198628643728                      10                   8
# 19775298  76561198628643728                      10                   8
# 19986651  76561198628643728                      10                   8
# 20462805  76561198628643728                      10                   8
#
#           author.playtime_forever  author.playtime_last_two_weeks  \
# 4195413                    4786.0                             0.0
# 17717812                   4821.0                             0.0
# 19775298                    329.0                             0.0
# 19986651                   2948.0                             0.0
# 20462805                  34334.0                             0.0
#
#           author.playtime_at_review  author.last_played
# 4195413                      1553.0        1.604190e+09
# 17717812                     1736.0        1.605396e+09
# 19775298                      329.0        1.602729e+09
# 19986651                     2945.0        1.604597e+09
# 20462805                    31047.0        1.607005e+09
#
# [5 rows x 23 columns]
